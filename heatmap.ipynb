# %%
from math import pi
import matplotlib.pyplot as plt
import matplotlib
matplotlib.style.use('ggplot')
import seaborn as sns
import numpy as np
import pandas as pd

data = pd.read_csv('dataset_3.csv')
df = data.pivot(index='HOMO_Energy', values='LUMO_Energy', columns='CSD_code')
df.head()
heatmap_plot = sns.heatmap(df, center=0, cmap='gist_ncar')
plt.show()
